# %%
#   Import relevant python packages 
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('job_vs_leave.csv')
df.head()
# Out:
#                       JobTitle  PersonType  SickLeaveHours
# 0                   Accountant           2              49
# 1  Accounts Payable Specialist           2              51
# 2           Control Specialist           2              57
# 3       Database Administrator           2              53
# 4   Document Control Assistant           2              59

# %%
plt.style.use('dark_background')
plt.title('JobTitle(PersonType) vs SickLeave(Hrs)' , color='royalblue', font='Georgia')
colors=('papayawhip','papayawhip','papayawhip','papayawhip','papayawhip','papayawhip','papayawhip','papayawhip','papayawhip','papayawhip','papayawhip','papayawhip','papayawhip','papayawhip', 'blanchedalmond', 'blanchedalmond','blanchedalmond','blanchedalmond','tan', 'tan', 'tan', 'tan','burlywood', 'orange', 'darkorange', 'goldenrod', 'darkgoldenrod' )
plt.barh(df.JobTitle, df.SickLeaveHours, color= colors)
plt.xlabel('AVERAGE SICK LEAVE HOURS TAKEN', color='royalblue', font='Georgia')

plt.show()
